# %%
import pandas as pd
import os
from sqlalchemy import create_engine

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Bao_cao_nhap_SX_thang_08.2020.XLSX',
#  'Bao_cao_nhap_xuat_ton_thang_08.2020.XLSX',
#  'Bao_cao_xuat_ban_thang_08.2020.XLSX',
#  'Danh_sách_khách_hàng_MP.xlsx',
#  'Finance',
#  'HỢP_ĐỒNG_CÒN_NỢ_CẬP_NHẬT_ĐẾN_05-11-2020.xlsx',
#  'LIST_CAN_DOI_THANH_PHAM_SAN_XUAT.xlsx',
#  'Material_Data_Danh_sach_mat_hang.XLSX',
#  'MinhPhu_DiemTin_Pro_DB_Design_v2.0.docx',
#  'MPG-Giá-bán-All-Ring.xlsx',
#  'MPG-Giá-bán-All.xlsx',
#  'MPG-Giá-nguyên-liệu.xlsx',
#  'MPG-Giá-thành.xlsx',
#  'MPG-Khối-lượng-còn-nợ.xlsx',
#  'MPG-Khối-lượng-thu-mua.xlsx',
#  'MPG-QUI_DINH_DAT_TEN_MA_THANH_PHAM.pdf',
#  'sales_order',
#  'Thuật ngữ MP.xlsx',
#  'Tồn_kho_chi_tiết_MPCM_05.11.xlsx',
#  'Untitled.ipynb',
#  'Vấn đề của data.txt',
#  '~$HỢP_ĐỒNG_CÒN_NỢ_CẬP_NHẬT_ĐẾN_05-11-2020.xlsx',
#  '~$LIST_CAN_DOI_THANH_PHAM_SAN_XUAT.xlsx']

# %%
from openpyxl import load_workbook

def iter_rows(ws):
    for row in ws.iter_rows():
        yield [cell.value for cell in row[:]]

def get_schema(fname):
    wb = load_workbook(fname) #from openpyxl import load_workbook
    ws = wb.active
    schema = pd.DataFrame(iter_rows(ws))
    schema.columns = schema.iloc[0]
    schema = schema.reindex(schema.index.drop(0))
    return schema

df = get_schema("Tồn_kho_chi_tiết_MPCM_05.11.xlsx")

# %%
df
# Out:
# 0     Nhà máy(Plant) Color Wire Mã kho S.Loc(S.Loc) Mã vật tư(Mat.Num.)  \
# 1               1000                           1204            50000018
# 2               1000                           1204            50000018
# 3               1000                           1217            50000062
# 4               1000                           1210            50000079
# 5               1000                           1210            50000079
# ...              ...        ...                 ...                 ...
# 24935           1000      NH.02                1204            50514962
# 24936           1000      NH.02                1204            50514962
# 24937           1000      NH.02                1204            50514962
# 24938           1000      NH.02                1204            50514962
# 24939
#
# 0                   Tên vật tư(Mat.Description)  \
# 1         BT T.Bột HEKAMR (0.5-3-9)18PE 91%TẠM1
# 2         BT T.Bột HEKAMR (0.5-3-9)18PE 91%TẠM1
# 3      BT BRD 2LSTK1N(10PX10X3)BRD.SHRIMP(36.5)
# 4         BT CHOSO 25CHOPKOTN (20X500G) JP.KOTN
# 5         BT CHOSO 25CHOPKOTN (20X500G) JP.KOTN
# ...                                         ...
# 24935        VM CPTO 51/60 (20X250G) NORDIC 080
# 24936        VM CPTO 51/60 (20X250G) NORDIC 080
# 24937        VM CPTO 51/60 (20X250G) NORDIC 080
# 24938        VM CPTO 51/60 (20X250G) NORDIC 080
# 24939
#
# 0     Số lượng tồn kho(ĐVT thay thế) ĐVT thay thế Số Lô(Batch)  \
# 1                                 16          KIE   DK12100100
# 2                                 16          KIE   DK12080199
# 3                                  1          KIE       DK2020
# 4                                 14          KIE   1000739467
# 5                                 10          KIE   1000741949
# ...                              ...          ...          ...
# 24935                              8          KIE   1000861970
# 24936                             47          KIE   1000861970
# 24937                              2          KIE   1000861970
# 24938                             56          KIE   1000861970
# 24939                         715720          KIE
#
# 0     Tồn kho theo(Special Stock Number) SO line  ...  \
# 1                                              0  ...
# 2                                              0  ...
# 3                                              0  ...
# 4                             1600027411      10  ...
# 5                             1600027411      10  ...
# ...                                  ...     ...  ...
# 24935                                          0  ...
# 24936                                          0  ...
# 24937                                          0  ...
# 24938                                          0  ...
# 24939                                             ...
#
# 0     Trạng thái vật tư(Stock Cat.) Số lượng tồn kho(ĐVT chính) BUN  \
# 1                   Available Stock                     130.896  KG
# 2                   Available Stock                     130.896  KG
# 3                      Unrestricted                         2.4  KG
# 4                      Unrestricted                         140  KG
# 5                      Unrestricted                         100  KG
# ...                             ...                         ...  ..
# 24935               Available Stock                          32  KG
# 24936               Available Stock                         188  KG
# 24937               Available Stock                           8  KG
# 24938               Available Stock                         224  KG
# 24939                                               5.24171e+06
#
# 0     Loại tồn kho(Special Stock) Code nhà máy Số lượng tồn kho(ĐVT KG2)  \
# 1                                                                    144
# 2                                                                    144
# 3                                                                  6.575
# 4                               E                                    140
# 5                               E                                    100
# ...                           ...          ...                       ...
# 24935                                                                 32
# 24936                                                                188
# 24937                                                                  8
# 24938                                                                224
# 24939                                                        5.53274e+06
#
# 0     ĐVT KG2         Bao bì Nhà cung cấp Tên khách hàng
# 1         KG2        TẠM 18*
# 2         KG2        TẠM 18*
# 3         KG2     JP.2LSTK1N
# 4         KG2  JP.25CHOPKOTN                KOBE TRADING
# 5         KG2  JP.25CHOPKOTN                KOBE TRADING
# ...       ...            ...          ...            ...
# 24935     KG2         NORDIC
# 24936     KG2         NORDIC
# 24937     KG2         NORDIC
# 24938     KG2         NORDIC
# 24939
#
# [24939 rows x 24 columns]

# %%
engine = create_engine("postgresql://postgres:mp_tla_server@128.199.194.183:5432/mp_tla")

# %%
import string
import re
from pyvi import ViUtils

# %%
# !pip install pyvi

# %%
patterns = "|".join([i for i in string.punctuation])

# %%
def remove_punct(test_str):
    for i in string.punctuation:
        if i in test_str:
            test_str = test_str.replace(i, " ")
    return test_str

# %%
def preprocess(a):
    a = " ".join(remove_punct(a).split())
    a = " ".join(a.lower().split())
    a = ViUtils.remove_accents(a)
    a = a.decode()
    a = " ".join(a.lower().split())
    a = a.replace(" ", "_")
    return a

# %%
preprocess("Nhà máy(Plant)")
# Out:
# 'nha_may_plant'

# %%
renames = dict()
for col in list(df.columns):
    renames[col] = preprocess(col)

# %%
renames
# Out:
# {'Nhà máy(Plant)': 'nha_may_plant',
#  'Color Wire': 'color_wire',
#  'Mã kho S.Loc(S.Loc)': 'ma_kho_s_loc_s_loc',
#  'Mã vật tư(Mat.Num.)': 'ma_vat_tu_mat_num',
#  'Tên vật tư(Mat.Description)': 'ten_vat_tu_mat_description',
#  'Số lượng tồn kho(ĐVT thay thế)': 'so_luong_ton_kho_dvt_thay_the',
#  'ĐVT thay thế': 'dvt_thay_the',
#  'Số Lô(Batch)': 'so_lo_batch',
#  'Tồn kho theo(Special Stock Number)': 'ton_kho_theo_special_stock_number',
#  'SO line': 'so_line',
#  'Ngày KHSX(Date of production plan)': 'ngay_khsx_date_of_production_plan',
#  'Ngày hết hạn sừ dụng(SLED/BBD)': 'ngay_het_han_su_dung_sled_bbd',
#  'Ngày nhập kho(GR Date)': 'ngay_nhap_kho_gr_date',
#  'Code truy xuất': 'code_truy_xuat',
#  'Trạng thái vật tư(Stock Cat.)': 'trang_thai_vat_tu_stock_cat',
#  'Số lượng tồn kho(ĐVT chính)': 'so_luong_ton_kho_dvt_chinh',
#  'BUN': 'bun',
#  'Loại tồn kho(Special Stock)': 'loai_ton_kho_special_stock',
#  'Code nhà máy': 'code_nha_may',
#  'Số lượng tồn kho(ĐVT KG2)': 'so_luong_ton_kho_dvt_kg2',
#  'ĐVT KG2': 'dvt_kg2',
#  'Bao bì': 'bao_bi',
#  'Nhà cung cấp': 'nha_cung_cap',
#  'Tên khách hàng': 'ten_khach_hang'}

# %%
df.rename(renames, axis = 1, inplace = True)

# %%
df = df[df["ma_vat_tu_mat_num"] != '']

# %%
df
# Out:
# 0     nha_may_plant color_wire ma_kho_s_loc_s_loc ma_vat_tu_mat_num  \
# 1              1000                          1204          50000018
# 2              1000                          1204          50000018
# 3              1000                          1217          50000062
# 4              1000                          1210          50000079
# 5              1000                          1210          50000079
# ...             ...        ...                ...               ...
# 24934          1000      NH.02               1204          50514962
# 24935          1000      NH.02               1204          50514962
# 24936          1000      NH.02               1204          50514962
# 24937          1000      NH.02               1204          50514962
# 24938          1000      NH.02               1204          50514962
#
# 0                    ten_vat_tu_mat_description so_luong_ton_kho_dvt_thay_the  \
# 1         BT T.Bột HEKAMR (0.5-3-9)18PE 91%TẠM1                            16
# 2         BT T.Bột HEKAMR (0.5-3-9)18PE 91%TẠM1                            16
# 3      BT BRD 2LSTK1N(10PX10X3)BRD.SHRIMP(36.5)                             1
# 4         BT CHOSO 25CHOPKOTN (20X500G) JP.KOTN                            14
# 5         BT CHOSO 25CHOPKOTN (20X500G) JP.KOTN                            10
# ...                                         ...                           ...
# 24934        VM CPTO 51/60 (20X250G) NORDIC 080                            58
# 24935        VM CPTO 51/60 (20X250G) NORDIC 080                             8
# 24936        VM CPTO 51/60 (20X250G) NORDIC 080                            47
# 24937        VM CPTO 51/60 (20X250G) NORDIC 080                             2
# 24938        VM CPTO 51/60 (20X250G) NORDIC 080                            56
#
# 0     dvt_thay_the so_lo_batch ton_kho_theo_special_stock_number so_line  ...  \
# 1              KIE  DK12100100                                         0  ...
# 2              KIE  DK12080199                                         0  ...
# 3              KIE      DK2020                                         0  ...
# 4              KIE  1000739467                        1600027411      10  ...
# 5              KIE  1000741949                        1600027411      10  ...
# ...            ...         ...                               ...     ...  ...
# 24934          KIE  1000861970                                         0  ...
# 24935          KIE  1000861970                                         0  ...
# 24936          KIE  1000861970                                         0  ...
# 24937          KIE  1000861970                                         0  ...
# 24938          KIE  1000861970                                         0  ...
#
# 0     trang_thai_vat_tu_stock_cat so_luong_ton_kho_dvt_chinh bun  \
# 1                 Available Stock                    130.896  KG
# 2                 Available Stock                    130.896  KG
# 3                    Unrestricted                        2.4  KG
# 4                    Unrestricted                        140  KG
# 5                    Unrestricted                        100  KG
# ...                           ...                        ...  ..
# 24934             Available Stock                        232  KG
# 24935             Available Stock                         32  KG
# 24936             Available Stock                        188  KG
# 24937             Available Stock                          8  KG
# 24938             Available Stock                        224  KG
#
# 0     loai_ton_kho_special_stock code_nha_may so_luong_ton_kho_dvt_kg2  \
# 1                                                                  144
# 2                                                                  144
# 3                                                                6.575
# 4                              E                                   140
# 5                              E                                   100
# ...                          ...          ...                      ...
# 24934                                                              232
# 24935                                                               32
# 24936                                                              188
# 24937                                                                8
# 24938                                                              224
#
# 0     dvt_kg2         bao_bi nha_cung_cap ten_khach_hang
# 1         KG2        TẠM 18*
# 2         KG2        TẠM 18*
# 3         KG2     JP.2LSTK1N
# 4         KG2  JP.25CHOPKOTN                KOBE TRADING
# 5         KG2  JP.25CHOPKOTN                KOBE TRADING
# ...       ...            ...          ...            ...
# 24934     KG2         NORDIC
# 24935     KG2         NORDIC
# 24936     KG2         NORDIC
# 24937     KG2         NORDIC
# 24938     KG2         NORDIC
#
# [24938 rows x 24 columns]

# %%
def get_product_type(a):   
    a = a.split()
    return a[0]

def get_process_type(a):
    a = a.split()
    return a[1]
def get_size(a):
    a = a.split()
    try:
        return a[2]
    except:
        print(a)
        pass

# %%
get_product_type('VM CPTO 51/60 (20X250G) NORDIC 080')
# Out:
# ('VM', 'CPTO', '51/60')

# %%
# Tạo thêm ba cột loại sản phẩm, loại chế biến, size, rất quan trọng vì phục vụ trực tiếp việc truy vấn của trợ lý ảo
df["loai_san_pham"] = df["ten_vat_tu_mat_description"].apply(get_product_type)
df["loai_che_bien"] = df["ten_vat_tu_mat_description"].apply(get_process_type)
df["size"] = df["ten_vat_tu_mat_description"].apply(get_size)
# Out:
# ['VM', 'BRD17VTBKOT3(10PX20X2)JP17VTBKOT3(35)']
# ['VM', 'NOBASHI20VKYSD(450GX20)DIAMO-DIAM0440']
# ['VM', 'NOBASHI20VKYSD(450GX20)DIAMO-DIAM0440']
# d:\anaconda\envs\mp_tla\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# d:\anaconda\envs\mp_tla\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# d:\anaconda\envs\mp_tla\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df
# Out:
# 0     nha_may_plant color_wire ma_kho_s_loc_s_loc ma_vat_tu_mat_num  \
# 1              1000                          1204          50000018
# 2              1000                          1204          50000018
# 3              1000                          1217          50000062
# 4              1000                          1210          50000079
# 5              1000                          1210          50000079
# ...             ...        ...                ...               ...
# 24934          1000      NH.02               1204          50514962
# 24935          1000      NH.02               1204          50514962
# 24936          1000      NH.02               1204          50514962
# 24937          1000      NH.02               1204          50514962
# 24938          1000      NH.02               1204          50514962
#
# 0                    ten_vat_tu_mat_description so_luong_ton_kho_dvt_thay_the  \
# 1         BT T.Bột HEKAMR (0.5-3-9)18PE 91%TẠM1                            16
# 2         BT T.Bột HEKAMR (0.5-3-9)18PE 91%TẠM1                            16
# 3      BT BRD 2LSTK1N(10PX10X3)BRD.SHRIMP(36.5)                             1
# 4         BT CHOSO 25CHOPKOTN (20X500G) JP.KOTN                            14
# 5         BT CHOSO 25CHOPKOTN (20X500G) JP.KOTN                            10
# ...                                         ...                           ...
# 24934        VM CPTO 51/60 (20X250G) NORDIC 080                            58
# 24935        VM CPTO 51/60 (20X250G) NORDIC 080                             8
# 24936        VM CPTO 51/60 (20X250G) NORDIC 080                            47
# 24937        VM CPTO 51/60 (20X250G) NORDIC 080                             2
# 24938        VM CPTO 51/60 (20X250G) NORDIC 080                            56
#
# 0     dvt_thay_the so_lo_batch ton_kho_theo_special_stock_number so_line  ...  \
# 1              KIE  DK12100100                                         0  ...
# 2              KIE  DK12080199                                         0  ...
# 3              KIE      DK2020                                         0  ...
# 4              KIE  1000739467                        1600027411      10  ...
# 5              KIE  1000741949                        1600027411      10  ...
# ...            ...         ...                               ...     ...  ...
# 24934          KIE  1000861970                                         0  ...
# 24935          KIE  1000861970                                         0  ...
# 24936          KIE  1000861970                                         0  ...
# 24937          KIE  1000861970                                         0  ...
# 24938          KIE  1000861970                                         0  ...
#
# 0     loai_ton_kho_special_stock code_nha_may so_luong_ton_kho_dvt_kg2  \
# 1                                                                  144
# 2                                                                  144
# 3                                                                6.575
# 4                              E                                   140
# 5                              E                                   100
# ...                          ...          ...                      ...
# 24934                                                              232
# 24935                                                               32
# 24936                                                              188
# 24937                                                                8
# 24938                                                              224
#
# 0     dvt_kg2         bao_bi nha_cung_cap ten_khach_hang loai_san_pham  \
# 1         KG2        TẠM 18*                                        BT
# 2         KG2        TẠM 18*                                        BT
# 3         KG2     JP.2LSTK1N                                        BT
# 4         KG2  JP.25CHOPKOTN                KOBE TRADING            BT
# 5         KG2  JP.25CHOPKOTN                KOBE TRADING            BT
# ...       ...            ...          ...            ...           ...
# 24934     KG2         NORDIC                                        VM
# 24935     KG2         NORDIC                                        VM
# 24936     KG2         NORDIC                                        VM
# 24937     KG2         NORDIC                                        VM
# 24938     KG2         NORDIC                                        VM
#
# 0     loai_che_bien                               size
# 1             T.Bột                             HEKAMR
# 2             T.Bột                             HEKAMR
# 3               BRD  2LSTK1N(10PX10X3)BRD.SHRIMP(36.5)
# 4             CHOSO                         25CHOPKOTN
# 5             CHOSO                         25CHOPKOTN
# ...             ...                                ...
# 24934          CPTO                              51/60
# 24935          CPTO                              51/60
# 24936          CPTO                              51/60
# 24937          CPTO                              51/60
# 24938          CPTO                              51/60
#
# [24938 rows x 27 columns]

# %%
df.to_sql("thanh_pham_ton_kho_chi_tiet", engine, if_exists = "replace")
